# %% [markdown]
# # Первичный анализ текстовых данных (NLP EDA)

# %% [markdown]
# ### Задание 1: Анализ распределения текста и предобработка
#
# Описание:
# Вы анализируете датасет с отзывами пользователей о продукте. Вам нужно провести первичный анализ текстовых данных и подготовить их к дальнейшей обработке.
# Требования:
#
# Используйте датасет Amazon Product Reviews или IMDB Reviews.
# Проведите анализ:
#
# Распределение длины текстов (количество символов, слов, предложений).
# Частотность слов (nltk.FreqDist, collections.Counter).
# Визуализируйте топ-20 самых частых слов (исключая стоп-слова) с помощью wordcloud и barplot.
#
# Выполните предобработку:
#
# Удаление стоп-слов, пунктуации, HTML-тегов (если есть).
# Лемматизация/стемминг (nltk.stem, spacy).
# Визуализируйте распределение длины текстов до и после предобработки.
#
# Дополнительно:
#
# Постройте график распределения тональности текстов (используйте TextBlob или VADER).

# %%
# https://www.kaggle.com/datasets/cynthiarempel/amazon-us-customer-reviews-dataset
# https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews

# %% [markdown]
# ### Задание 2: Анализ n-грамм и TF-IDF
# Описание:
# Вы хотите понять, какие фразы и слова наиболее характерны для положительных и отрицательных отзывов.
# Требования:
#
# Используйте тот же датасет отзывов.
# Постройте:
#
# Распределение биграмм и триграмм для положительных и отрицательных отзывов (nltk.ngrams).
# TF-IDF матрицу (sklearn.feature_extraction.text.TfidfVectorizer).
#
# Визуализируйте:
#
# Топ-10 биграмм для каждого класса (положительный/отрицательный) с помощью barplot.
# Heatmap TF-IDF для топ-20 слов.
#
# Дополнительно:
#
# Примените PCA для визуализации TF-IDF в 2D и сравните кластеры положительных/отрицательных отзывов.

# %% [markdown]
# ### Задание 3: Топик-моделирование (LDA, NMF)
# Описание:
# Вы анализируете новостные статьи и хотите выявить основные темы.
# Требования:
#
# Используйте датасет BBC News Archive или 20 Newsgroups.
# Примените:
#
# LDA (sklearn.decomposition.LatentDirichletAllocation).
# NMF (sklearn.decomposition.NMF).
#
# Визуализируйте:
#
# Распределение тем по документам (pyLDAvis).
# Топ-10 слов для каждой темы.
#
# Дополнительно:
#
# Сравните результаты LDA и NMF: какие темы лучше интерпретируются?

# %%
# https://www.kaggle.com/datasets/pariza/bbc-news-summary
# https://www.kaggle.com/datasets/abhishek/20-newsgroups
