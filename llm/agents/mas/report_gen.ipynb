# %% [markdown]
# # Мультиагентная система для генерации отчета по заданной теме

# %% [markdown]
# ![Building-Your-First-Multi-Agent-System-A-Beginners-Guide_3.png](attachment:Building-Your-First-Multi-Agent-System-A-Beginners-Guide_3.png)
#
# Наша многоагентная системная сетевая архитектура супервизора.

# %% [markdown]
# у нас будет четыре специализированных агента:
#
#     Агент веб-исследователя
#     Аналитик трендов
#     Агент по написанию отчетов
#     Корректор

# %% [markdown]
# Агент-менеджер руководит всеми этими агентами, которые выполняют свои задачи только по указанию. Кроме того, агент-исследователь имеет доступ к инструменту веб-поиска для поиска в интернете и исследования по заданной теме.

# %% [markdown]
# будем использовать агента CrewAI , который отлично подходит для создания многоагентной системы.

# %%
# !pip install crewai langchain-community pydantic
# Out:
# ...
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    ------- -------------------------------- 1.6/8.7 MB 9.7 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.9/8.7 MB 10.2 MB/s eta 0:00:01
#    --------------------------- ------------ 6.0/8.7 MB 10.3 MB/s eta 0:00:01
#    ------------------------------------- -- 8.1/8.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.7/8.7 MB 9.3 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ------------------------------ --------- 1.6/2.0 MB 8.0 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 7.2 MB/s  0:00:00
# Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# ...
# Using cached json5-0.12.1-py3-none-any.whl (36 kB)
# ...

# %%
import os
from dotenv import load_dotenv

# %%
load_dotenv()

OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY")

# %%
from crewai import Crew, Task, Agent, Process, LLM
from pydantic import BaseModel
from crewai.tools.structured_tool import CrewStructuredTool
from langchain.chat_models import ChatOpenAI

# %%
llm = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    openai_api_key=OPENROUTER_API_KEY,
    model_name="gpt-4o-mini"
)
