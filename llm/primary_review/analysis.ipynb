# %% [markdown]
# # Первичный анализ данных для LLM

# %% [markdown]
# ### Задание 7: Анализ распределения длины и качества текстов для fine-tuning LLM
#
# Описание:
# Вы готовите датасет для fine-tuning большой языковой модели и хотите оценить его качество.
# Требования:
#
# Используйте датасет Stanford Question Answering Dataset (SQuAD) или Common Crawl.
# Проведите анализ:
#
# Распределение длины текстов (в токенах) с помощью transformers (tokenizer).
# Частотность специальных токенов (например, [CLS], [SEP]).
#
# Визуализируйте:
#
# Гистограмму распределения длины текстов.
# Boxplot для выявления выбросов.
#
# Оцените, какие тексты могут быть слишком короткими/длинными для обучения LLM.
# Дополнительно:
#
# Постройте график распределения тем (используйте BERTopic или LDA).

# %%
# https://rajpurkar.github.io/SQuAD-explorer/
# https://commoncrawl.org/

# %% [markdown]
# ### Задание 8: Оценка разнообразия и качества ответов LLM
#
# Описание:
# Вы тестируете LLM на датасете вопросов и хотите оценить разнообразие и качество её ответов.
# Требования:
#
# Используйте датасет ELI5 или MS MARCO.
# Сгенерируйте ответы с помощью LLM (например, transformers).
# Проведите анализ:
#
# Длина ответов (гистограмма).
# Уникальность ответов (например, с помощью n-gram overlap).
# Качество ответов (метрики BLEU, ROUGE).
#
# Визуализируйте:
#
# Распределение метрик качества.
# Wordcloud для наиболее частых слов в ответах.
#
# Дополнительно:
#
# Сравните ответы LLM с эталонными ответами с помощью BERTScore.

# %%
# https://huggingface.co/datasets/eli5
# https://microsoft.github.io/MSMARCO/

# %% [markdown]
# ### Задание 9: Анализ смещений (biases) в текстах для LLM
#
# Описание:
# Вы хотите выявить потенциальные смещения (гендерные, расовые) в текстах, используемых для обучения LLM.
# Требования:
#
# Используйте датасет Bias in Open-Ended Language Generation (BOLD).
# Проведите анализ:
#
# Частотность упоминаний гендерных/расовых групп.
# Контекст упоминаний (положительный/отрицательный) с помощью TextBlob или VADER.
#
# Визуализируйте:
#
# Barplot частотности упоминаний.
# Heatmap контекстов (положительный/нейтральный/отрицательный).
#
# Дополнительно:
#
# Примените PCA или t-SNE для визуализации кластеров текстов с разными смещениями.
