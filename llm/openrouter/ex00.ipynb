# %%
import os
from dotenv import load_dotenv
import requests
import json
from openai import OpenAI

# %%
load_dotenv()

OPENROUTER_API_KEY = os.environ.get("OPENROUTER_API_KEY")

# %%
# # URL API
# url = "https://openrouter.ai/api/v1/chat/completions"

# # Заголовки
# headers = {
#     "Authorization": f"Bearer {OPENROUTER_API_KEY}",
#     "Content-Type": "application/json",
# }

# # Данные запроса
# payload = {
#     "model": "deepseek/deepseek-chat-v3-0324:free",
#     "messages": [
#         {"role": "system", "content": "Вы полезный помощник."},
#         {"role": "user", "content": "Объясните квантовые вычисления простыми словами."}
#     ],
#     "temperature": 0.7,
#     "max_tokens": 1000
# }

# response = requests.post(url, headers=headers, data=json.dumps(payload))

# # Вывод
# result = response.json()
# print(result)
# Out:
# {'error': {'message': 'Provider returned error', 'code': 429, 'metadata': {'raw': 'deepseek/deepseek-chat-v3-0324:free is temporarily rate-limited upstream. Please retry shortly, or add your own key to accumulate your rate limits: https://openrouter.ai/settings/integrations', 'provider_name': 'Chutes'}}, 'user_id': 'user_30K7HBt2mEdlewgli4xnWCQOg97'}

# %%
client = OpenAI(
  base_url="https://openrouter.ai/api/v1",
  api_key=OPENROUTER_API_KEY,
)

completion = client.chat.completions.create(
  model="openai/gpt-4o",
  messages=[
    {
      "role": "user",
      "content": "Write code create vulkan 2d game with lua scripts"
    }
  ]
)

print(completion.choices[0].message.content)
# Out:
# Creating a 2D game using Vulkan with Lua scripting involves several components, including setting up Vulkan, incorporating a scripting system with Lua, and integrating these pieces with a game loop and rendering framework. Below is a simplified step-by-step outline with some code snippets to guide you through setting up the basic framework. This is a high-level overview and won't cover every detail, as Vulkan and Lua integration would be extensive for a fully functioning game.
#
# ### Prerequisites
# 1. **Vulkan SDK** - Ensure you have the Vulkan SDK installed on your system.
# 2. **Lua** - Install the Lua library to facilitate scripting.
# 3. **GLFW or SDL** - For windowing and input handling.
# 4. **GLM** - For matrix and vector math (optional but recommended).
#
# ### Project Setup
# Start by creating a basic project structure:
#
# ```
# my_vulkan_game/
# ├── scripts/
# │   └── main.lua
# ├── shaders/
# │   ├── vert.spv
# │   └── frag.spv
# ├── src/
# │   ├── main.cpp
# │   ├── vulkan_setup.cpp
# │   ├── vulkan_setup.hpp
# │   ├── lua_integration.cpp
# │   └── lua_integration.hpp
# └── CMakeLists.txt
# ```
#
# ### CMakeLists.txt
# Assuming you use CMake to manage your build:
#
# ```cmake
# cmake_minimum_required(VERSION 3.10)
#
# project(MyVulkanGame)
#
# find_package(Vulkan REQUIRED)
# find_package(Lua REQUIRED)
# find_package(glfw3 REQUIRED)
#
# include_directories(${Vulkan_INCLUDE_DIRS} ${LUA_INCLUDE_DIR} ${GLFW_INCLUDE_DIRS})
#
# add_executable(MyVulkanGame src/main.cpp src/vulkan_setup.cpp src/lua_integration.cpp)
# target_link_libraries(MyVulkanGame Vulkan::Vulkan ${LUA_LIBRARIES} glfw)
# ```
#
# ### Vulkan Setup (`vulkan_setup.cpp`)
# Initialize Vulkan and prepare for rendering 2D graphics. This part involves creating an instance, physical and logical devices, swap chains, image views, etc.
#
# ```cpp
# #include "vulkan_setup.hpp"
#
# // Implement Vulkan setup functions
#
# void initVulkan() {
#     // 1. Create Vulkan instance
#     // 2. Setup Debug Messenger (optional)
#     // 3. Select physical device
#     // 4. Create logical device and queues
#     // 5. Create swap chain
#     // 6. Create image views
#     // 7. Create render pass
#     // 8. Create graphics pipeline
#     // 9. Create framebuffers
#     // 10. Create command pools and buffers
# }
#
# void cleanupVulkan() {
#     // Cleanup resources
# }
# ```
#
# ### Lua Integration (`lua_integration.cpp`)
# Set up Lua integration to run scripts and perform game logic.
#
# ```cpp
# #include "lua_integration.hpp"
# #include <lua.hpp>
#
# lua_State *L;
#
# void initLua() {
#     L = luaL_newstate();    // Create a new Lua state
#     luaL_openlibs(L);       // Initialize Lua standard libraries
# }
#
# void runLuaScript(const std::string &scriptPath) {
#     if (luaL_dofile(L, scriptPath.c_str())) {
#         // Error handling
#         std::cerr << lua_tostring(L, -1);
#     }
# }
#
# void cleanupLua() {
#     lua_close(L);
# }
# ```
#
# ### Main Source (`main.cpp`)
# Bring everything together and create a basic game loop.
#
# ```cpp
# #include "vulkan_setup.hpp"
# #include "lua_integration.hpp"
#
# int main() {
#     initVulkan();
#     initLua();
#
#     runLuaScript("scripts/main.lua");
#
#     // Main loop for rendering and updating
#     while (!shouldClose()) {
#         // Handle events
#         // Update game state based on Lua scripts
#         // Render frame
#     }
#
#     cleanupLua();
#     cleanupVulkan();
#
#     return 0;
# }
# ```
#
# ### Lua Script (`scripts/main.lua`)
# Define game logic and behavior using Lua.
#
# ```lua
# -- main.lua
#
# function update()
#     -- Update game logic here
#     print("Updating Game State")
# end
#
# function render()
#     -- Render 2D objects here
#     print("Rendering Frame")
# end
#
# -- Loop system, typically plugged into the main loop
# -- while true do
# --    update()
# --    render()
# --    sleep(1/60)  -- Assuming 60 FPS
# -- end
# ```
#
# ### Building and Running
# 1. **Build with CMake**.
# 2. **Run the executable**.
# 3. Test the Lua integration by scripting logic and rendering in Lua.
#
# This setup provides a basic framework for a 2D Vulkan game with Lua scripting. For actual rendering, you'll need shaders (GLSL converted to SPIR-V), proper Vulkan resource management, and handling of synchronization mechanisms like semaphores and command buffers. Lua integration allows the game logic and other behaviors to be scripted outside the compiled code, which is essential for games that require flexibility or modding capabilities.

# %%
url = "https://openrouter.ai/api/v1/chat/completions"

headers = {
    "Authorization": f"Bearer {OPENROUTER_API_KEY}",
    "Content-Type": "application/json",
}

payload = {
    "model": "deepseek/deepseek-chat-v3.1",
    "messages": [
        {"role": "system", "content": "Вы полезный помощник."},
        {"role": "user", "content": "Объясните квантовые вычисления простыми словами."}
    ],
    "temperature": 0.7,
    "max_tokens": 1000
}

response = requests.post(url, headers=headers, data=json.dumps(payload))

result = response.json()
print(result["choices"][0]["message"]["content"])
# Out:
# Конечно! Объясню квантовые вычисления на простой аналогии.
#
# ### Представьте себе гигантский лабиринт
#
# **Обычный компьютер (классический)** подходит к нему как один человек. Он проверяет каждый коридор по очереди: зашел в тупик — вернулся, пошел проверять следующий. На это уходит очень много времени, особенно если лабиринт огромный.
#
# **Квантовый компьютер** подходит к этому лабиринту как волшебник. Он создаёт своего «квантового двойника» для каждого входа в лабиринт одновременно. Все эти двойники проходят все пути **параллельно** и почти мгновенно находят правильный выход.
#
# ### В чём же волшебство? Три главных принципа:
#
# #### 1. Кубиты (квантовые биты)
# *   **Обычный бит** — это как выключатель: он может быть только **ВКЛ (1)** или **ВЫКЛ (0)**.
# *   **Кубит** — это как spinning-монетка, которая вращается. Пока она вращается, она не «орёл» и не «решка», а **и то, и другое одновременно** с какой-то вероятностью. Это состояние называется **суперпозиция**.
#
# Именно это позволяет кубиту обрабатывать оба значения (0 и 1) сразу.
#
# #### 2. Квантовая запутанность
# Если мы свяжем два кубита (запутаем их), они станут единой системой. Изменив состояние одного кубита, вы **мгновенно** измените состояние другого, даже если они находятся на oppositeих концах галактики. Это создаёт невероятно мощные связи между данными, которые обычные компьютеры воспроизвести не могут.
#
# #### 3. Квантовая интерференция
# В нашем лабиринте не все пути правильные. Квантовый компьютер использует интерференцию — как волны в воде — чтобы **погасить (уничтожить)** сигналы от неправильных путей и **усилить** сигнал от правильного. В итоге при измерении мы с большой вероятностью получаем именно верный ответ.
#
# ### Простыми словами: что это даёт?
#
# Квантовый компьютер **не заменит ваш ноутбук**. Он не будет быстрее запускать Windows или крутить игры.
#
# Его сила в решении **конкретных типов задач**, которые обычным компьютерам не под силу:
#
# *   **Взлом шифрования:** Современная защита в интернете основана на том, что обычному компьютеру потребуются тысячи лет, чтобы подобрать ключ. Квантовый компьютер сможет сделать это за часы или минуты.
# *   **Разработка лекарств:** Можно будет с высочайшей точностью смоделировать молекулу и понять, как она будет взаимодействовать с другими, что ускорит создание новых лекарств в разы.
# *   **Оптимизация систем:** Найти самый быстрый маршрут для тысяч машин одновременно, оптимально распределить энергию по всей стране и т.д.
#
# ### Важный нюанс
#
# Когда квантовый компьютер заканчивает вычисления и мы «смотрим» на результат (производим измерение), его «волшебное» состояние суперпозиции **исчезает**. Он возвращает нам один конкретный ответ, как обычный компьютер, но этот ответ — результат гениальной работы со всеми возможностями сразу.
#
# **Итог:** Квантовые вычисления — это использование законов квантовой физики (суперпозиции и запутанности) для одновременного расчёта множества вариантов и быстрого нахождения решения среди них. Это не «более быстрый процессор», а принципиально **новый способ вычислений**.
